# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshyadavofficial/handsign/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q inference supervision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.6/846.6 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 44.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.9/891.9 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 6.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
from inference import get_model
Roboflow_api_key = '8IMh8dZwwuwdCDPqfbTL'
MODEL_ID = 'signlanguagedetection-jsb85/1'
model = get_model(MODEL_ID, Roboflow_api_key)

# %%
import cv2

# %%
Image_path = "/content/test.jpg"
image = cv2.imread(Image_path)

# %%
results = model.infer(image,confidence=0.4)[0]

# %%
results
# Out:
# ObjectDetectionInferenceResponse(visualization=None, inference_id=None, frame_id=None, time=None, image=InferenceResponseImage(width=300, height=300), predictions=[ObjectDetectionPrediction(x=151.5, y=149.5, width=221.0, height=297.0, confidence=0.7174190282821655, class_name='A', class_confidence=None, class_id=0, tracker_id=None, detection_id='16d2f1dc-4f95-4770-a8de-78e2e8c141ad', parent_id=None)])

# %%
import supervision as sv
detections = sv.Detections.from_inference(results)

# %%
detections
# Out:
# Detections(xyxy=array([[         41,           1,         262,         298]]), mask=None, confidence=array([    0.71742]), class_id=array([0]), tracker_id=None, data={'class_name': array(['A'], dtype='<U1')})

# %%
annotated_image = image.copy()
annotated_image = sv.BoxAnnotator().annotate(annotated_image, detections=detections)
annotated_image = sv.LabelAnnotator().annotate(annotated_image, detections=detections)

# %%
sv.plot_image(annotated_image)
